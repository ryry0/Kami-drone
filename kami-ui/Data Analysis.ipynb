# %%
using PyPlot;
using DataFrames;

# %%
# Out:
# Saw 726 rows, 22 columns and 15987 fields
#  * Line 1 has 39 columns
#
#
# Stacktrace:
#  [1] findcorruption(::Int64, ::Int64, ::Int64, ::DataFrames.ParsedCSV) at /home/ryan/.julia/v0.6/DataFrames/src/dataframe/io.jl:712
#  [2] readtable!(::DataFrames.ParsedCSV, ::IOStream, ::Int64, ::DataFrames.ParseOptions{String,String}) at /home/ryan/.julia/v0.6/DataFrames/src/dataframe/io.jl:788
#  [3] #readtable#84(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::IOStream, ::Int64) at /home/ryan/.julia/v0.6/DataFrames/src/dataframe/io.jl:851
#  [4] (::DataFrames.#kw##readtable)(::Array{Any,1}, ::DataFrames.#readtable, ::IOStream, ::Int64) at ./<missing>:0
# ...

# %%
filenames = readdir("../data915/stripped")

for i in 1:length(filenames)
    data = readtable("../data915/stripped/$(filenames[i])")
    plot(data[:l_knee_angle])
    title("$(filenames[i])")
    figure()
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d15b3a20>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d16c6828>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d1185358>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7cc642cc0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7cc95ff60>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d123e438>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d1323320>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7cc4c4080>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d11d4588>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7cc6bff28>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d117aac8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff7d15eb7f0>)
# ...

# %%
data
# Out:
# data (generic function with 1 method)
